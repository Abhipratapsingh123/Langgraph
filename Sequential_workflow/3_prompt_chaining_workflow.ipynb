# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model='gemini-2.5-flash',temperature=0.6)

# %%
# defining State

class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
# function of create_outline node

def create_outline(state:BlogState)->BlogState:
    # fetch title
    title = state['title']
    # call llm and gen outline
    prompt = f'Generate an outline for a blog on the topic: {title}'
    
    outline = model.invoke(prompt).content
    
    # update the state
    
    state['outline'] = outline
    
    return state

# %%
# function of create blog node
def create_blog(state:BlogState)->BlogState:
    title = state['title']
    outline = state['outline']
    
    # call llm and gen a blog on the above outline
    prompt=  f'Write a detailed blog on the title  - {title}, using the following outline \n {outline}'
    
    content = model.invoke(prompt).content
    
    # update the State
    
    state['content'] = content
    
    
    return state

# %%
graph = StateGraph(BlogState)

# nodes of the graph
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)


# edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

# compile the graph

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here\'s an outline for a blog post on "The Rise of AI in India," designed to be comprehensive, engaging, and easy to read.\n\n---\n\n## Blog Title Options:\n\n*   The AI Wave: India\'s Ascent in the Global AI Landscape\n*   Decoding India\'s AI Boom: Opportunities, Challenges, and the Road Ahead\n*   From Silicon Valley to Bangalore: Charting India\'s AI Revolution\n*   India\'s Intelligent Future: How AI is Reshaping the Nation\n\n---\n\n## Blog Outline: The Rise of AI in India\n\n**Target Audience:** Tech enthusiasts, business professionals, policymakers, students, and anyone interested in India\'s technological advancements.\n\n---\n\n### I. Introduction (Approx. 150 words)\n\n*   **Hook:** Start with a bold statement about AI\'s global impact and its transformative power.\n*   **Context:** Briefly introduce India\'s unique position – a tech-savvy nation with a massive digital footprint and a burgeoning economy.\n*   **Thesis Statement:** State that India is rapidly emerging as a significant player in the global AI landscape, driven by unique factors and addressing distinct challenges.\n*   **Roadmap:** Briefly mention what the blog will cover (drivers, applications, challenges, future).\n\n### II. The Driving Forces Behind India\'s AI Boom (Approx. 300 words)\n\n*   **A. Abundant Talent Pool:**\n    *   Large number of STEM graduates, engineers, and data scientists.\n    *   Growing ecosystem of AI education and skill development programs.\n*   **B. Digital Infrastructure & Data Proliferation:**\n    *   Massive internet penetration (Jio revolution).\n    *   UPI, Aadhaar, and other digital public goods generating vast amounts of data.\n    *   Growing use of smartphones and digital services.\n*   **C. Government Push & Policy Support:**\n    *   "AI for All" vision and the National Strategy for Artificial Intelligence.\n    *   NITI Aayog\'s initiatives, emphasis on responsible AI.\n    *   Investment in AI research and development centers.\n*   **D. Vibrant Startup Ecosystem & Investment:**\n    *   Rise of AI-focused startups across various sectors.\n    *   Increasing venture capital funding and corporate investments in AI.\n    *   Incubators and accelerators fostering innovation.\n*   **E. Cost-Effectiveness & Frugal Innovation:**\n    *   Ability to develop affordable AI solutions tailored for mass adoption.\n\n### III. AI\'s Transformative Impact Across Key Indian Sectors (Approx. 400 words)\n\n*   **A. Healthcare:**\n    *   Diagnostic tools (e.g., for ophthalmology, radiology).\n    *   Drug discovery and personalized medicine.\n    *   Predictive analytics for disease outbreaks.\n    *   Telemedicine and remote patient monitoring.\n*   **B. Agriculture:**\n    *   Precision farming (crop monitoring, yield prediction).\n    *   Pest and disease detection.\n    *   Market price prediction and supply chain optimization.\n    *   Automated irrigation and drone-based surveys.\n*   **C. Finance (FinTech):**\n    *   Fraud detection and risk assessment.\n    *   Personalized banking services and chatbots.\n    *   Credit scoring for underserved populations.\n    *   Algorithmic trading.\n*   **D. Education:**\n    *   Personalized learning paths and adaptive tutoring.\n    *   Automated grading and content recommendation.\n    *   Administrative efficiency for institutions.\n*   **E. E-commerce & Retail:**\n    *   Recommendation engines and personalized shopping experiences.\n    *   Customer service chatbots and virtual assistants.\n    *   Inventory management and supply chain optimization.\n*   **F. Public Services & Governance:**\n    *   Smart cities initiatives (traffic management, waste disposal).\n    *   Disaster management and early warning systems.\n    *   Public grievance redressal systems.\n\n### IV. Unique Contributions & "AI for Good" in India (Approx. 200 words)\n\n*   **A. Vernacular AI:** Breaking language barriers with AI in diverse regional languages.\n ...

# %%
print(final_state['outline'])
# Out:
# Here's an outline for a blog post on "The Rise of AI in India," designed to be comprehensive, engaging, and easy to read.
#
# ---
#
# ## Blog Title Options:
#
# *   The AI Wave: India's Ascent in the Global AI Landscape
# *   Decoding India's AI Boom: Opportunities, Challenges, and the Road Ahead
# *   From Silicon Valley to Bangalore: Charting India's AI Revolution
# *   India's Intelligent Future: How AI is Reshaping the Nation
#
# ---
#
# ## Blog Outline: The Rise of AI in India
#
# **Target Audience:** Tech enthusiasts, business professionals, policymakers, students, and anyone interested in India's technological advancements.
#
# ---
#
# ### I. Introduction (Approx. 150 words)
#
# *   **Hook:** Start with a bold statement about AI's global impact and its transformative power.
# *   **Context:** Briefly introduce India's unique position – a tech-savvy nation with a massive digital footprint and a burgeoning economy.
# *   **Thesis Statement:** State that India is rapidly emerging as a significant player in the global AI landscape, driven by unique factors and addressing distinct challenges.
# *   **Roadmap:** Briefly mention what the blog will cover (drivers, applications, challenges, future).
#
# ### II. The Driving Forces Behind India's AI Boom (Approx. 300 words)
#
# *   **A. Abundant Talent Pool:**
#     *   Large number of STEM graduates, engineers, and data scientists.
#     *   Growing ecosystem of AI education and skill development programs.
# *   **B. Digital Infrastructure & Data Proliferation:**
#     *   Massive internet penetration (Jio revolution).
#     *   UPI, Aadhaar, and other digital public goods generating vast amounts of data.
#     *   Growing use of smartphones and digital services.
# *   **C. Government Push & Policy Support:**
#     *   "AI for All" vision and the National Strategy for Artificial Intelligence.
#     *   NITI Aayog's initiatives, emphasis on responsible AI.
#     *   Investment in AI research and development centers.
# *   **D. Vibrant Startup Ecosystem & Investment:**
#     *   Rise of AI-focused startups across various sectors.
#     *   Increasing venture capital funding and corporate investments in AI.
#     *   Incubators and accelerators fostering innovation.
# *   **E. Cost-Effectiveness & Frugal Innovation:**
#     *   Ability to develop affordable AI solutions tailored for mass adoption.
#
# ### III. AI's Transformative Impact Across Key Indian Sectors (Approx. 400 words)
#
# *   **A. Healthcare:**
#     *   Diagnostic tools (e.g., for ophthalmology, radiology).
#     *   Drug discovery and personalized medicine.
#     *   Predictive analytics for disease outbreaks.
#     *   Telemedicine and remote patient monitoring.
# *   **B. Agriculture:**
#     *   Precision farming (crop monitoring, yield prediction).
#     *   Pest and disease detection.
#     *   Market price prediction and supply chain optimization.
#     *   Automated irrigation and drone-based surveys.
# *   **C. Finance (FinTech):**
#     *   Fraud detection and risk assessment.
#     *   Personalized banking services and chatbots.
#     *   Credit scoring for underserved populations.
#     *   Algorithmic trading.
# *   **D. Education:**
#     *   Personalized learning paths and adaptive tutoring.
#     *   Automated grading and content recommendation.
#     *   Administrative efficiency for institutions.
# *   **E. E-commerce & Retail:**
#     *   Recommendation engines and personalized shopping experiences.
#     *   Customer service chatbots and virtual assistants.
#     *   Inventory management and supply chain optimization.
# *   **F. Public Services & Governance:**
#     *   Smart cities initiatives (traffic management, waste disposal).
#     *   Disaster management and early warning systems.
#     *   Public grievance redressal systems.
#
# ### IV. Unique Contributions & "AI for Good" in India (Approx. 200 words)
#
# *   **A. Vernacular AI:** Breaking language barriers with AI in diverse regional languages.
# *   **B. Inclusive AI:** Focus on solutions for rural populations and marginalized communities.
# *   **C. Societal Impact:** Addressing grand challenges like poverty, literacy, and climate change through AI.
# *   **D. Global Collaboration:** India's role in global AI research and standards development.
#
# ### V. Challenges and the Road Ahead (Approx. 250 words)
#
# *   **A. Skill Gap:** Need for advanced research skills, specialized AI talent beyond basic implementation.
# *   **B. Ethical AI & Bias:**
#     *   Addressing data bias in diverse datasets.
#     *   Ensuring fairness, accountability, and transparency in AI systems.
#     *   Developing robust ethical guidelines and frameworks.
# *   **C. Data Privacy & Security:**
#     *   Robust data protection laws and implementation (e.g., upcoming DPD Bill).
#     *   Safeguarding sensitive personal and national data.
# *   **D. Infrastructure Gaps:**
#     *   Ensuring equitable access to high-speed internet in remote areas.
#     *   Availability of high-performance computing resources.
# *   **E. Job Displacement & Reskilling:**
#     *   Mitigating potential job losses due to automation.
#     *   Investing in lifelong learning and reskilling programs for the workforce.
#
# ### VI. Conclusion (Approx. 100 words)
#
# *   **Recap:** Briefly summarize India's rapid AI growth, driven by talent, data, and policy, impacting multiple sectors.
# *   **Reiterate Thesis:** Emphasize India's potential to not just adopt but also lead in specific areas of AI innovation, especially "AI for Good."
# *   **Future Outlook:** Look forward to India's continued journey as a global AI powerhouse, navigating challenges to create an intelligent and inclusive future.
# *   **Call to Action/Thought Provoker:** Encourage readers to engage with the opportunities and responsibilities that come with this technological revolution.
#
# ---

# %%
print(final_state['content'])
# Out:
# ## India's Intelligent Future: How AI is Reshaping the Nation
#
# Artificial Intelligence (AI) is not merely a technological advancement; it's a paradigm shift, poised to redefine industries, economies, and societies across the globe. In this seismic transformation, one nation is rapidly carving out a unique and influential position: India. With its colossal digital population, burgeoning tech talent, and an economy poised for exponential growth, India is rapidly emerging as a formidable force in the global AI landscape. Far from simply adopting foreign innovations, the subcontinent is developing indigenous AI solutions tailored to its distinct needs and diverse challenges. This blog post will delve into the unique drivers propelling India's AI boom, explore its widespread applications across key sectors, highlight its distinctive contributions, and examine the crucial challenges and the road ahead for this intelligent future.
#
# ### The Driving Forces Behind India's AI Boom
#
# India's burgeoning AI ecosystem isn't a fluke; it's the result of several powerful, interconnected forces:
#
# **A. Abundant Talent Pool:** India boasts one of the world's largest pools of STEM graduates, engineers, and data scientists. Educational institutions are increasingly integrating AI and machine learning into their curricula, complemented by a growing ecosystem of online courses and skill development programs designed to churn out industry-ready AI professionals.
#
# **B. Digital Infrastructure & Data Proliferation:** The "Jio revolution" has brought affordable internet to hundreds of millions, transforming India into a data-rich nation. Platforms like UPI (Unified Payments Interface), Aadhaar (the world's largest biometric ID system), and a plethora of other digital public goods generate vast amounts of transactional and behavioral data daily, providing fertile ground for AI model training and deployment. The pervasive use of smartphones further fuels this data engine.
#
# **C. Government Push & Policy Support:** The Indian government has articulated a clear vision for AI, encapsulated in its "AI for All" strategy and the National Strategy for Artificial Intelligence. NITI Aayog, the government's premier think tank, is at the forefront, emphasizing responsible AI development, ethical guidelines, and investment in AI research and development centers to foster a robust innovation ecosystem.
#
# **D. Vibrant Startup Ecosystem & Investment:** India’s startup scene is booming, with AI-focused ventures emerging across diverse sectors from healthcare to logistics. This entrepreneurial spirit is backed by increasing venture capital funding, corporate investments, and a growing network of incubators and accelerators dedicated to nurturing AI innovation.
#
# **E. Cost-Effectiveness & Frugal Innovation:** India has a proven track record of "frugal innovation"—developing high-quality, affordable solutions. This approach extends to AI, enabling the creation of cost-effective AI tools and platforms tailored for mass adoption, particularly in developing regions.
#
# ### AI's Transformative Impact Across Key Indian Sectors
#
# AI is not just a buzzword in India; it's a practical tool revolutionizing everyday life and economic activity:
#
# **A. Healthcare:** AI is making healthcare more accessible and efficient. It powers diagnostic tools for early detection of diseases like diabetic retinopathy and specific cancers in radiology. AI accelerates drug discovery, enables personalized medicine by analyzing genomic data, and predicts disease outbreaks, aiding public health interventions. Telemedicine platforms, often AI-enhanced, are extending reach to remote areas, facilitating remote patient monitoring.
#
# **B. Agriculture:** In a nation where agriculture is the backbone, AI offers revolutionary solutions. Precision farming techniques utilize AI for crop monitoring, yield prediction, and optimizing irrigation. AI models detect pests and diseases early, predict market prices for produce, and streamline supply chains. Drone-based surveys and automated irrigation systems are becoming increasingly common, helping farmers make data-driven decisions.
#
# **C. Finance (FinTech):** The FinTech sector is a prime beneficiary. AI-driven systems excel at fraud detection and real-time risk assessment. Personalized banking services, powered by chatbots and recommendation engines, enhance customer experience. Critically, AI is enabling credit scoring for underserved populations who lack traditional credit histories, fostering greater financial inclusion. Algorithmic trading also sees significant AI application.
#
# **D. Education:** AI is reshaping learning. It facilitates personalized learning paths, adapting content to individual student needs and pace, and offering adaptive tutoring. Automated grading systems free up educators' time, and AI recommends relevant educational content, making learning more engaging and efficient. AI also streamlines administrative tasks for educational institutions.
#
# **E. E-commerce & Retail:** From recommending products you might like to optimizing delivery routes, AI is at the heart of India's booming e-commerce. Recommendation engines and personalized shopping experiences drive sales, while customer service chatbots and virtual assistants handle queries efficiently. AI also optimizes inventory management and supply chain logistics, reducing costs and improving delivery times.
#
# **F. Public Services & Governance:** AI is instrumental in "Smart Cities" initiatives, managing traffic flow, optimizing waste disposal, and monitoring public safety. It plays a role in disaster management through early warning systems and resource allocation. AI-powered public grievance redressal systems enhance accountability and efficiency in governance, making services more citizen-centric.
#
# ### Unique Contributions & "AI for Good" in India
#
# India's approach to AI is distinguished by its focus on inclusivity and societal impact, often termed "AI for Good."
#
# **A. Vernacular AI:** With over 22 official languages and hundreds of dialects, language is a significant barrier to digital inclusion. India is pioneering vernacular AI, developing natural language processing (NLP) and voice interfaces that can understand and respond in diverse regional languages, bringing AI benefits to a broader population.
#
# **B. Inclusive AI:** There's a strong focus on creating AI solutions specifically for rural populations and marginalized communities. This includes AI applications that improve access to education, healthcare, and financial services in remote areas, ensuring technology benefits extend beyond urban centers.
#
# **C. Societal Impact:** Indian AI research and deployment often target grand challenges like poverty alleviation, improving literacy rates, and addressing climate change. From using AI for water management to optimizing energy consumption, the goal is to leverage technology for tangible societal upliftment.
#
# **D. Global Collaboration:** India is not just a recipient but an active contributor to global AI research and standards development. Its researchers and startups are increasingly collaborating with international counterparts, sharing insights and contributing to the global discourse on responsible and ethical AI.
#
# ### Challenges and the Road Ahead
#
# Despite the impressive progress, India's AI journey faces several critical challenges that need strategic navigation.
#
# **A. Skill Gap:** While India has a large STEM talent pool, there's a significant demand for highly specialized AI researchers and engineers beyond basic implementation. Bridging this skill gap requires continuous investment in advanced AI education, research infrastructure, and attracting top global talent.
#
# **B. Ethical AI & Bias:** India's immense diversity presents unique challenges in developing unbiased AI systems. Ensuring data used for training AI models is representative and addressing algorithmic bias is crucial to prevent discriminatory outcomes. Developing robust ethical guidelines, transparency, and accountability frameworks is paramount.
#
# **C. Data Privacy & Security:** With vast amounts of data being generated, robust data protection laws and their stringent implementation are essential. The upcoming Digital Personal Data Protection (DPD) Bill aims to address this, but safeguarding sensitive personal and national data from breaches and misuse remains a continuous challenge.
#
# **D. Infrastructure Gaps:** While internet penetration is high, ensuring equitable access to high-speed internet in remote and rural areas is still a hurdle. Furthermore, the availability of high-performance computing (HPC) resources, crucial for training complex AI models, needs to expand to support the growing demand.
#
# **E. Job Displacement & Reskilling:** The automation brought about by AI raises concerns about potential job displacement in certain sectors. Proactive measures, including investing in lifelong learning programs, reskilling initiatives for the existing workforce, and fostering new job creation in AI-related fields, are vital to mitigate adverse social impacts.
#
# ### Conclusion
#
# India's rise as an AI powerhouse is undeniable, driven by its unique combination of abundant talent, vast digital data, strong government support, and a dynamic startup ecosystem. AI is already transforming sectors from healthcare to agriculture, offering tailored solutions and fostering significant societal impact through its "AI for Good" philosophy. While navigating challenges like skill gaps, ethical considerations, data privacy, and potential job displacement, India's strategic approach promises a future where AI not only drives economic growth but also promotes inclusivity and addresses complex societal issues. As India continues its journey, its unique contributions and commitment to responsible innovation are poised to make it a leader in shaping a truly intelligent and equitable global future. The AI wave is here, and India is riding it with purpose and vision.

# %%
from IPython.display import Image

Image(workflow.get_graph().draw_mermaid_png())
